# %% [markdown]
# # CSV FIles

# %% [markdown]
# # Writing csv

# %%
import pandas as pd

# %%
dic =  pd.DataFrame({"A":[1,2,3,4,5],"B":[6,7,8,9,10], "C":[1,3,5,6,7]})
d = pd.DataFrame(dic)
print(d)
d.to_csv("new_csv.csv")
# Out:
#    A   B  C
# 0  1   6  1
# 1  2   7  3
# 2  3   8  5
# 3  4   9  6
# 4  5  10  7

# %%
d.to_csv("new1.csv", index = False)

# %% [markdown]
# # Reading csv

# %%
import pandas as pd

# %%
data = pd.read_csv("dataset_titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
data = pd.read_csv("dataset_titanic.csv", usecols = ["Name","Sex"])
data
# Out:
#                                              Name     Sex
# 0                                Kelly, Mr. James    male
# 1                Wilkes, Mrs. James (Ellen Needs)  female
# 2                       Myles, Mr. Thomas Francis    male
# 3                                Wirz, Mr. Albert    male
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..                                            ...     ...
# 413                            Spector, Mr. Woolf    male
# 414                  Oliva y Ocana, Dona. Fermina  female
# 415                  Saether, Mr. Simon Sivertsen    male
# 416                           Ware, Mr. Frederick    male
# 417                      Peter, Master. Michael J    male
#
# [418 rows x 2 columns]

# %%
data2 = pd.read_csv("dataset_titanic.csv", skiprows=[3])
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            895         0       3
# 3            896         1       3
# 4            897         0       3
# ..           ...       ...     ...
# 412         1305         0       3
# 413         1306         1       1
# 414         1307         0       3
# 415         1308         0       3
# 416         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                                Wirz, Mr. Albert    male  27.0      0      0
# 3    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 4                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
data3 = pd.read_csv("dataset_titanic.csv", index_col="PassengerId")
data3
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 892                 0       3                              Kelly, Mr. James
# 893                 1       3              Wilkes, Mrs. James (Ellen Needs)
# 894                 0       2                     Myles, Mr. Thomas Francis
# 895                 0       3                              Wirz, Mr. Albert
# 896                 1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ...               ...     ...                                           ...
# 1305                0       3                            Spector, Mr. Woolf
# 1306                1       1                  Oliva y Ocana, Dona. Fermina
# 1307                0       3                  Saether, Mr. Simon Sivertsen
# 1308                0       3                           Ware, Mr. Frederick
# 1309                0       3                      Peter, Master. Michael J
#
# ...

# %%
data3 = pd.read_csv("dataset_titanic.csv", header = 2)
data3
# Out:
#       893  1  3              Wilkes, Mrs. James (Ellen Needs)  female    47  \
# 0     894  0  2                     Myles, Mr. Thomas Francis    male  62.0
# 1     895  0  3                              Wirz, Mr. Albert    male  27.0
# 2     896  1  3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0
# 3     897  0  3                    Svensson, Mr. Johan Cervin    male  14.0
# 4     898  1  3                          Connolly, Miss. Kate  female  30.0
# ..    ... .. ..                                           ...     ...   ...
# 411  1305  0  3                            Spector, Mr. Woolf    male   NaN
# 412  1306  1  1                  Oliva y Ocana, Dona. Fermina  female  39.0
# 413  1307  0  3                  Saether, Mr. Simon Sivertsen    male  38.5
# 414  1308  0  3                           Ware, Mr. Frederick    male   NaN
# 415  1309  0  3                      Peter, Master. Michael J    male   NaN
#
#      1.1  0              363272         7 Unnamed: 10  S
# ...

# %%
data4 = pd.read_csv("dataset_titanic.csv", names=["col1"])
data4
# Out:
#                                                                                                                            col1
# PassengerId Survived Pclass Name                             Sex    Age  SibSp Parch Ticket             Fare    Cabin  Embarked
# 892         0        3      Kelly, Mr. James                 male   34.5 0     0     330911             7.8292  NaN           Q
# 893         1        3      Wilkes, Mrs. James (Ellen Needs) female 47   1     0     363272             7       NaN           S
# 894         0        2      Myles, Mr. Thomas Francis        male   62   0     0     240276             9.6875  NaN           Q
# 895         0        3      Wirz, Mr. Albert                 male   27   0     0     315154             8.6625  NaN           S
# ...                                                                                                                         ...
# ...

# %%
data5 = pd.read_csv("dataset_titanic.csv", header = None, )
data5
# Out:
#               0         1       2                                 3       4   \
# 0    PassengerId  Survived  Pclass                              Name     Sex
# 1            892         0       3                  Kelly, Mr. James    male
# 2            893         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 3            894         0       2         Myles, Mr. Thomas Francis    male
# 4            895         0       3                  Wirz, Mr. Albert    male
# ..           ...       ...     ...                               ...     ...
# 414         1305         0       3                Spector, Mr. Woolf    male
# 415         1306         1       1      Oliva y Ocana, Dona. Fermina  female
# 416         1307         0       3      Saether, Mr. Simon Sivertsen    male
# 417         1308         0       3               Ware, Mr. Frederick    male
# 418         1309         0       3          Peter, Master. Michael J    male
#
# ...

# %%
data5 = pd.read_csv("dataset_titanic.csv",)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 data5 = pd.read_csv("dataset_titanic.csv",  prefix ="col10")
#
# TypeError: read_csv() got an unexpected keyword argument 'prefix'
