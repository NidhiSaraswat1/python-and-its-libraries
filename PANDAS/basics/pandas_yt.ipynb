# %% [markdown]
# # ARITHEMATIC OPERATIONS

# %%
import pandas as pd

# %%
var =  pd.DataFrame({"A":[1,2,3,4,5],"B":[6,7,8,9,10]})
var
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
var["C"] = var["A"]+ var["B"]
var
# Out:
#    A   B   c   C
# 0  1   6   7   7
# 1  2   7   9   9
# 2  3   8  11  11
# 3  4   9  13  13
# 4  5  10  15  15

# %%
var["C"] = var["A"]- var["B"]
var
# Out:
#    A   B   c  C
# 0  1   6   7 -5
# 1  2   7   9 -5
# 2  3   8  11 -5
# 3  4   9  13 -5
# 4  5  10  15 -5

# %%
var["M"] = var["A"]* var["B"]
var
# Out:
#    A   B   c  C   M
# 0  1   6   7 -5   6
# 1  2   7   9 -5  14
# 2  3   8  11 -5  24
# 3  4   9  13 -5  36
# 4  5  10  15 -5  50

# %%
var1 =  pd.DataFrame({"A":[10,20,30,40,50],"B":[60,70,80,90,100]})
var1
# Out:
#     A    B
# 0  10   60
# 1  20   70
# 2  30   80
# 3  40   90
# 4  50  100

# %%
var1["python"] = var1["A"]<= 20
var1
# Out:
#     A    B  python
# 0  10   60    True
# 1  20   70    True
# 2  30   80   False
# 3  40   90   False
# 4  50  100   False

# %% [markdown]
# # Insert

# %%
var2 =  pd.DataFrame({"A":[1,2,3,4,5],"B":[6,7,8,9,10]})
var2
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
var2.insert(2,"C",[3,5,7,8,1])
var2
# Out:
#    A   B  C
# 0  1   6  3
# 1  2   7  5
# 2  3   8  7
# 3  4   9  8
# 4  5  10  1

# %%
var2["D"] = var2["A"][4]
var2
# Out:
#    A   B  C  D
# 0  1   6  3  5
# 1  2   7  5  5
# 2  3   8  7  5
# 3  4   9  8  5
# 4  5  10  1  5

# %% [markdown]
# # Delete

# %%
var2.pop("D")
# Out:
# 0    5
# 1    5
# 2    5
# 3    5
# 4    5
# Name: D, dtype: int64

# %%
var2
# Out:
#    A   B
# 0  1   6
# 1  2   7
# 2  3   8
# 3  4   9
# 4  5  10

# %%
del var2["A"]
var2
# Out:
#     B
# 0   6
# 1   7
# 2   8
# 3   9
# 4  10

# %%
var
